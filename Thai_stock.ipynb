# %%
# !pip install pandas_datareader
# Out:
# Requirement already satisfied: pandas_datareader in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (0.9.0)
# Requirement already satisfied: lxml in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from pandas_datareader) (4.5.1)
# Requirement already satisfied: pandas>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from pandas_datareader) (1.0.5)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from pandas_datareader) (2.24.0)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from pandas>=0.23->pandas_datareader) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from pandas>=0.23->pandas_datareader) (2.8.1)
# Requirement already satisfied: numpy>=1.13.3 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from pandas>=0.23->pandas_datareader) (1.18.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests>=2.19.0->pandas_datareader) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests>=2.19.0->pandas_datareader) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests>=2.19.0->pandas_datareader) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests>=2.19.0->pandas_datareader) (1.25.9)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas>=0.23->pandas_datareader) (1.15.0)

# %%
import pandas as pd
import pandas_datareader.data as web
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

from bs4 import BeautifulSoup
import requests

import urllib
import string

# %%
Alphabet= string.ascii_uppercase[:26]
Alphabet = list(Alphabet)
Alphabet.append("NUMBER")
url = []

stock = pd.DataFrame()

for c, element in enumerate(Alphabet):
    urlx = "https://www.set.or.th/set/commonslookup.do?language=th&country=TH&prefix={}".format(element)
    url.append(urlx)

url_df = pd.DataFrame(Alphabet,columns = ["Index"])
url_df['url'] = url

# %%
stock = []
for j in url_df['url']:
    source = requests.get(j).text
    soup = BeautifulSoup(source, 'html.parser')       
    table_rows = soup.find_all("tr")
    for tr in table_rows:
        td = tr.find_all("td")
        row = [tr.text for tr in td]
        stock.append(row)

# %%
columns = ["Symbol", "Thai name", "Market"]
stock_sym = pd.DataFrame(stock, columns = columns)
stock_sym.dropna( axis=0, inplace=True)
stock_sym['Symbol'] = stock_sym['Symbol']+".BK"
stock_sym.head()
# Out:
#      Symbol                                 Thai name Market
# 1      A.BK  บริษัท อารียา พรอพเพอร์ตี้ จำกัด (มหาชน)    SET
# 2     A5.BK    บริษัท แอสเซท ไฟว์ กรุ๊ป จำกัด (มหาชน)    mai
# 3    AAV.BK    บริษัท เอเชีย เอวิเอชั่น จำกัด (มหาชน)    SET
# 4  ABICO.BK    บริษัท เอบิโก้ โฮลดิ้งส์ จำกัด (มหาชน)    mai
# 5    ABM.BK       บริษัท เอเชีย ไบโอแมส จำกัด (มหาชน)    mai

# %%
stock_sym.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 812 entries, 1 to 838
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Symbol     812 non-null    object
#  1   Thai name  812 non-null    object
#  2   Market     812 non-null    object
# dtypes: object(3)
# memory usage: 25.4+ KB

# %%
Sym_SET = stock_sym[stock_sym["Market"]=="SET"]
Sym_S = Sym_SET["Symbol"]
Sym_S = Sym_S.reset_index(drop = True)

# %%
def get_mean_dif3 (Major):
   
        for i in Major:
            s1 = datetime.now() - timedelta(400)
            s2 = datetime.now() - timedelta(2)
        
            start_date = "{0}-{1}-{2}".format(s1.day, s1.month, s1.year)
            end_date = "{0}-{1}-{2}".format(s2.day, s2.month, s2.year)

            DF = web.get_data_yahoo(i,start=start_date,end=end_date)
            
            DF1 = DF[["Adj Close"]]
            DF1["Mean35"] = DF.rolling(35).mean()[["Adj Close"]]
            DF1["Dif"] = abs(DF1["Adj Close"]-DF1['Mean35'])
            mean_dif = DF1["Dif"].mean()
        
            DFtotal = DF.merge(DF1, on = "Date")
            DFtotal.drop(columns = ["Adj Close_y"], inplace = True)
            DFtotalP = DFtotal.copy()
            DFtotalP["Dif Pct"] = (DFtotalP["Dif"]/DFtotalP["Adj Close_x"])*100
            DFtotalP.dropna(inplace =True, axis = 0)
            Dper = DFtotalP["Dif Pct"][-1]
            Price = DFtotalP["Adj Close_x"][-1]
        
        
            if DF1.loc[end_date]["Dif"] < mean_dif*3 :
                print("{} Yesterday price is {} trend still going, Diff percent from Moving average Day 35 is {} %".format(i, Price, Dper))
            else :
                print("!!! {} price is {} Check Price ,Diff percent from Moving average Day 35 ({} %) is too High !!!".format(i, Price, Dper))

        
        print(datetime.now())

# %%
get_mean_dif3(Sym_S)
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# A.BK Yesterday price is 4.980000019073486 trend still going, Diff percent from Moving average Day 35 is 0.25243835658935093 %
# AAV.BK Yesterday price is 2.299999952316284 trend still going, Diff percent from Moving average Day 35 is 4.645964321947256 %
# ABPIF.BK Yesterday price is 2.9600000381469727 trend still going, Diff percent from Moving average Day 35 is 0.154440005164199 %
# ACC.BK Yesterday price is 0.5400000214576721 trend still going, Diff percent from Moving average Day 35 is 4.285709712871348 %
# ACE.BK Yesterday price is 3.700000047683716 trend still going, Diff percent from Moving average Day 35 is 0.7876436581234169 %
# ACG.BK Yesterday price is 1.159999966621399 trend still going, Diff percent from Moving average Day 35 is 1.0098550997831057 %
# ADVANC.BK Yesterday price is 177.0 trend still going, Diff percent from Moving average Day 35 is 2.154963680387411 %
# AEC.BK Yesterday price is 0.2199999988079071 trend still going, Diff percent from Moving average Day 35 is 2.8571426636212864 %
# AEONTS.BK Yesterday price is 203.0 trend still going, Diff percent from Moving average Day 35 is 4.327938071780432 %
# AFC.BK Yesterday price is 5.800000190734863 trend still going, Diff percent from Moving average Day 35 is 1.4285676702491186 %
# AGE.BK Yesterday price is 1.809999942779541 trend still going, Diff percent from Moving average Day 35 is 1.7521671722633514 %
# AH.BK Yesterday price is 18.700000762939453 trend still going, Diff percent from Moving average Day 35 is 2.4140606879551245 %
# AHC.BK Yesterday price is 14.199999809265137 trend still going, Diff percent from Moving average Day 35 is 1.6498976531868936 %
# AI.BK Yesterday price is 2.180000066757202 trend still going, Diff percent from Moving average Day 35 is 4.2857175667038145 %
# AIMCG.BK Yesterday price is 5.800000190734863 trend still going, Diff percent from Moving average Day 35 is 1.9950703965478693 %
# AIMIRT.BK Yesterday price is 12.199999809265137 trend still going, Diff percent from Moving average Day 35 is 3.442623853344811 %
# AIT.BK Yesterday price is 17.899999618530273 trend still going, Diff percent from Moving average Day 35 is 0.3511588741528188 %
# AJ.BK Yesterday price is 18.600000381469727 trend still going, Diff percent from Moving average Day 35 is 2.9032230514240327 %
# AJA.BK Yesterday price is 0.14000000059604645 trend still going, Diff percent from Moving average Day 35 is 7.755103887170104 %
# AKR.BK Yesterday price is 0.6399999856948853 trend still going, Diff percent from Moving average Day 35 is 9.999997871262634 %
# ALLA.BK Yesterday price is 1.2699999809265137 trend still going, Diff percent from Moving average Day 35 is 4.386948049583123 %
# !!! ALT.BK price is 3.2799999713897705 Check Price ,Diff percent from Moving average Day 35 (305.57491593123035 %) is too High !!!
# ALUCON.BK Yesterday price is 168.5 trend still going, Diff percent from Moving average Day 35 is 0.2119542178889384 %
# AMANAH.BK Yesterday price is 3.9800000190734863 trend still going, Diff percent from Moving average Day 35 is 6.532664586052374 %
# AMARIN.BK Yesterday price is 4.320000171661377 trend still going, Diff percent from Moving average Day 35 is 3.4259299337336744 %
# AMATA.BK Yesterday price is 16.299999237060547 trend still going, Diff percent from Moving average Day 35 is 1.9106091015337698 %
# AMATAR.BK Yesterday price is 10.199999809265137 trend still going, Diff percent from Moving average Day 35 is 0.05602182231271397 %
# AMATAV.BK Yesterday price is 5.5 trend still going, Diff percent from Moving average Day 35 is 0.15584326409675048 %
# AMC.BK Yesterday price is 2.2200000286102295 trend still going, Diff percent from Moving average Day 35 is 4.646075985411665 %
# ANAN.BK Yesterday price is 2.0199999809265137 trend still going, Diff percent from Moving average Day 35 is 1.9519086452837016 %
# AOT.BK Yesterday price is 59.75 trend still going, Diff percent from Moving average Day 35 is 5.908536939512662 %
# AP.BK Yesterday price is 7.400000095367432 trend still going, Diff percent from Moving average Day 35 is 1.7181457018262754 %
# APCO.BK Yesterday price is 3.700000047683716 trend still going, Diff percent from Moving average Day 35 is 1.111968037182257 %
# APCS.BK Yesterday price is 4.940000057220459 trend still going, Diff percent from Moving average Day 35 is 4.366684350641781 %
# APEX.BK Yesterday price is 0.05999999865889549 trend still going, Diff percent from Moving average Day 35 is 9.047620732869468 %
# APURE.BK Yesterday price is 2.319999933242798 trend still going, Diff percent from Moving average Day 35 is 4.408863798171036 %
# AQ.BK Yesterday price is 0.019999999552965164 trend still going, Diff percent from Moving average Day 35 is 5.714285714285718 %
# AQUA.BK Yesterday price is 0.44999998807907104 trend still going, Diff percent from Moving average Day 35 is 4.888886626645526 %
# AS.BK Yesterday price is 7.050000190734863 trend still going, Diff percent from Moving average Day 35 is 10.536982783637857 %
# ASAP.BK Yesterday price is 1.7799999713897705 trend still going, Diff percent from Moving average Day 35 is 7.33547371734581 %
# ASEFA.BK Yesterday price is 3.5999999046325684 trend still going, Diff percent from Moving average Day 35 is 3.6984098369691765 %
# ASIA.BK Yesterday price is 4.940000057220459 trend still going, Diff percent from Moving average Day 35 is 1.5037593259205018 %
# ASIAN.BK Yesterday price is 13.100000381469727 trend still going, Diff percent from Moving average Day 35 is 13.55507331737692 %
# !!! ASIMAR.BK price is 1.9500000476837158 Check Price ,Diff percent from Moving average Day 35 (18.666669368161617 %) is too High !!!
# ASK.BK Yesterday price is 22.200000762939453 trend still going, Diff percent from Moving average Day 35 is 1.8275452995898354 %
# ASP.BK Yesterday price is 2.259999990463257 trend still going, Diff percent from Moving average Day 35 is 2.5284447155765144 %
# AWC.BK Yesterday price is 4.679999828338623 trend still going, Diff percent from Moving average Day 35 is 3.217343272564685 %
# AYUD.BK Yesterday price is 33.25 trend still going, Diff percent from Moving average Day 35 is 2.126745435016107 %
# !!! B.BK price is 0.5 Check Price ,Diff percent from Moving average Day 35 (20.74285728590829 %) is too High !!!
# B-WORK.BK Yesterday price is 11.199999809265137 trend still going, Diff percent from Moving average Day 35 is 0.20407876537418754 %
# B52.BK Yesterday price is 0.33000001311302185 trend still going, Diff percent from Moving average Day 35 is 6.666669203949422 %
# BA.BK Yesterday price is 6.650000095367432 trend still going, Diff percent from Moving average Day 35 is 0.3866791797749446 %
# BAFS.BK Yesterday price is 24.200000762939453 trend still going, Diff percent from Moving average Day 35 is 0.6493472510479448 %
# BAM.BK Yesterday price is 21.100000381469727 trend still going, Diff percent from Moving average Day 35 is 3.6289751640355243 %
# BANPU.BK Yesterday price is 10.399999618530273 trend still going, Diff percent from Moving average Day 35 is 2.060435706039318 %
# BAY.BK Yesterday price is 32.0 trend still going, Diff percent from Moving average Day 35 is 6.294642857142863 %
# BBL.BK Yesterday price is 122.0 trend still going, Diff percent from Moving average Day 35 is 1.0421545667447314 %
# BCH.BK Yesterday price is 14.699999809265137 trend still going, Diff percent from Moving average Day 35 is 6.316810852988104 %
# BCP.BK Yesterday price is 24.399999618530273 trend still going, Diff percent from Moving average Day 35 is 7.236532864929597 %
# BCPG.BK Yesterday price is 15.600000381469727 trend still going, Diff percent from Moving average Day 35 is 4.725277089978524 %
# BCT.BK Yesterday price is 42.5 trend still going, Diff percent from Moving average Day 35 is 0.11764705882352272 %
# BDMS.BK Yesterday price is 21.100000381469727 trend still going, Diff percent from Moving average Day 35 is 1.1509804075266556 %
# BEAUTY.BK Yesterday price is 1.7200000286102295 trend still going, Diff percent from Moving average Day 35 is 4.053157956009044 %
# BEC.BK Yesterday price is 7.699999809265137 trend still going, Diff percent from Moving average Day 35 is 1.5769921730584568 %
# BEM.BK Yesterday price is 8.25 trend still going, Diff percent from Moving average Day 35 is 4.4329011595094325 %
# BFIT.BK Yesterday price is 30.0 trend still going, Diff percent from Moving average Day 35 is 2.7380952380952435 %
# BGC.BK Yesterday price is 10.600000381469727 trend still going, Diff percent from Moving average Day 35 is 0.7547131495566142 %
# BGRIM.BK Yesterday price is 51.75 trend still going, Diff percent from Moving average Day 35 is 0.3726708074534165 %
# BH.BK Yesterday price is 125.0 trend still going, Diff percent from Moving average Day 35 is 0.8 %
# BIG.BK Yesterday price is 0.6100000143051147 trend still going, Diff percent from Moving average Day 35 is 0.37470549792393393 %
# BJC.BK Yesterday price is 35.5 trend still going, Diff percent from Moving average Day 35 is 1.7102615694164904 %
# BJCHI.BK Yesterday price is 1.7400000095367432 trend still going, Diff percent from Moving average Day 35 is 5.730705668292069 %
# BKD.BK Yesterday price is 1.809999942779541 trend still going, Diff percent from Moving average Day 35 is 4.404107272933582 %
# BKER.BK Yesterday price is 6.050000190734863 trend still going, Diff percent from Moving average Day 35 is 2.951596695085115 %
# BKI.BK Yesterday price is 270.0 trend still going, Diff percent from Moving average Day 35 is 1.4814814814814816 %
# BKKCP.BK Yesterday price is 11.399999618530273 trend still going, Diff percent from Moving average Day 35 is 1.4185492433335023 %
# BLA.BK Yesterday price is 23.700000762939453 trend still going, Diff percent from Moving average Day 35 is 3.339364034570855 %
# BLAND.BK Yesterday price is 1.1299999952316284 trend still going, Diff percent from Moving average Day 35 is 5.764854867813394 %
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas_datareader/yahoo/daily.py in _read_one_data(self, url, params)
#     156             j = json.loads(re.search(ptrn, resp.text, re.DOTALL).group(1))
# --> 157             data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
#     158         except KeyError:
#
# KeyError: 'HistoricalPriceStore'
#
# During handling of the above exception, another exception occurred:
#
# RemoteDataError                           Traceback (most recent call last)
# <ipython-input-105-f94828001ecf> in <module>
# ----> 1 get_mean_dif3(Sym_S)
#
# <ipython-input-104-7ef8717f196b> in get_mean_dif3(Major)
#       8             end_date = "{0}-{1}-{2}".format(s2.day, s2.month, s2.year)
#       9
# ---> 10             DF = web.get_data_yahoo(i,start=start_date,end=end_date)
#      11
#      12             DF1 = DF[["Adj Close"]]
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas_datareader/data.py in get_data_yahoo(*args, **kwargs)
#      84
#      85 def get_data_yahoo(*args, **kwargs):
# ---> 86     return YahooDailyReader(*args, **kwargs).read()
#      87
#      88
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas_datareader/base.py in read(self)
#     251         # If a single symbol, (e.g., 'GOOG')
#     252         if isinstance(self.symbols, (string_types, int)):
# --> 253             df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     254         # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     255         elif isinstance(self.symbols, DataFrame):
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas_datareader/yahoo/daily.py in _read_one_data(self, url, params)
#     158         except KeyError:
#     159             msg = "No data fetched for symbol {} using {}"
# --> 160             raise RemoteDataError(msg.format(symbol, self.__class__.__name__))
#     161
#     162         # price data
#
# RemoteDataError: No data fetched for symbol BLISS.BK using YahooDailyReader

# %%
def get_max (Major):
    try:
        for i in Major:
            s1 = datetime.now() - timedelta(400)
            s2 = datetime.now() - timedelta(2)
        
            start_date = "{0}-{1}-{2}".format(s1.day, s1.month, s1.year)
            end_date = "{0}-{1}-{2}".format(s2.day, s2.month, s2.year)

            DF = web.get_data_yahoo(i,start=start_date,end=end_date)   
        
            if DF['Volume'].iloc[-1] < DF['Volume'].max() :
                print("{} today volume is not max" .format(i))
            else :
                print("!!!{} today volume is max!!!" .format(i))
    except:
        print("ทำยังไงต่อวะ?")

        print(datetime.now())

# %%
get_max(Sym_S)
# Out:
# A.BK today volume is not max
# AAV.BK today volume is not max
# ABPIF.BK today volume is not max
# ACC.BK today volume is not max
# ACE.BK today volume is not max
# ACG.BK today volume is not max
# ADVANC.BK today volume is not max
# AEC.BK today volume is not max
# AEONTS.BK today volume is not max
# AFC.BK today volume is not max
# AGE.BK today volume is not max
# AH.BK today volume is not max
# AHC.BK today volume is not max
# AI.BK today volume is not max
# AIMCG.BK today volume is not max
# AIMIRT.BK today volume is not max
# AIT.BK today volume is not max
# AJ.BK today volume is not max
# AJA.BK today volume is not max
# AKR.BK today volume is not max
# ALLA.BK today volume is not max
# ALT.BK today volume is not max
# ALUCON.BK today volume is not max
# AMANAH.BK today volume is not max
# AMARIN.BK today volume is not max
# AMATA.BK today volume is not max
# AMATAR.BK today volume is not max
# AMATAV.BK today volume is not max
# AMC.BK today volume is not max
# ANAN.BK today volume is not max
# AOT.BK today volume is not max
# AP.BK today volume is not max
# APCO.BK today volume is not max
# APCS.BK today volume is not max
# APEX.BK today volume is not max
# APURE.BK today volume is not max
# AQ.BK today volume is not max
# AQUA.BK today volume is not max
# AS.BK today volume is not max
# ASAP.BK today volume is not max
# ASEFA.BK today volume is not max
# ASIA.BK today volume is not max
# ASIAN.BK today volume is not max
# ASIMAR.BK today volume is not max
# ASK.BK today volume is not max
# ASP.BK today volume is not max
# AWC.BK today volume is not max
# AYUD.BK today volume is not max
# B.BK today volume is not max
# B-WORK.BK today volume is not max
# B52.BK today volume is not max
# BA.BK today volume is not max
# BAFS.BK today volume is not max
# BAM.BK today volume is not max
# BANPU.BK today volume is not max
# BAY.BK today volume is not max
# BBL.BK today volume is not max
# BCH.BK today volume is not max
# BCP.BK today volume is not max
# BCPG.BK today volume is not max
# BCT.BK today volume is not max
# BDMS.BK today volume is not max
# BEAUTY.BK today volume is not max
# BEC.BK today volume is not max
# BEM.BK today volume is not max
# BFIT.BK today volume is not max
# BGC.BK today volume is not max
# BGRIM.BK today volume is not max
# BH.BK today volume is not max
# BIG.BK today volume is not max
# BJC.BK today volume is not max
# BJCHI.BK today volume is not max
# BKD.BK today volume is not max
# !!!BKER.BK today volume is max!!!
# BKI.BK today volume is not max
# BKKCP.BK today volume is not max
# BLA.BK today volume is not max
# BLAND.BK today volume is not max
# ทำยังไงต่อวะ?
# 2021-01-24 11:56:50.589001
